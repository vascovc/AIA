# %% [markdown]
# Encoder-Decoder Model

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,LSTM,Bidirectional,Flatten,TimeDistributed,ConvLSTM2D,RepeatVector
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from datetime import datetime
import sys

from read_files import read_files

import matplotlib.pyplot as plt

# %%
path = "C:/Users/Vasco/OneDrive - Universidade de Aveiro/Grupo/AIA/" #o teu path
path = "C:/Users/Vasco Costa/OneDrive - Universidade de Aveiro/Grupo/AIA/" #o teu path
product_group_id = 958 #depende da pasta
time_series_folder = 1 #1,2,3

df_long, df_wide = read_files(path,product_group_id,time_series_folder)
product_information = pd.read_pickle(path+"Data/product_information")
#print(product_information.loc[product_group_id])
#print(df_wide)
#print(df_wide.columns)
i = 1
plt.figure()
for col in df_wide.columns:
    plt.subplot(len(df_wide.columns), 1, i)
    plt.plot(df_wide[col].values)
    plt.title(col)
    i += 1
plt.show()

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in,n_steps_out):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the sequence
        if out_end_ix > len(sequence):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X),np.array(y)

# %%
methods= ["linear","time","slinear","quadratic","cubic","barycentric",
          "krogh", "from_derivatives", "pchip", "akima", "cubicspline"]
orders = ["polynomial","spline"]
methods += orders
order = 5

method = methods[1]
#for name in df_wide.columns:
if method in orders:
    df_wide.interpolate(option=method,order=order,inplace=True,limit_direction="both")
else:
    df_wide.interpolate(option=method,inplace=True,limit_direction="both")

i = 1
plt.figure()
for col in df_wide.columns:
    plt.subplot(len(df_wide.columns), 1, i)
    plt.plot(df_wide[col].values)
    plt.title(col)
    i += 1
plt.show()

# %%
company = "Abcdin"
raw_seq = df_wide[company]
n_steps_in  = 3
n_steps_out = 2
X, y = split_sequence(raw_seq, n_steps_in,n_steps_out)
percent_train = 0.8
value = int(len(X)*percent_train)
#print(len(X))
X_train = X[:value]
#print(len(X_train))
y_train = y[:value]
X_test = X[value:]
#print(len(X_test))
y_test = y[value:]

# %% [markdown]
# Encoder Decoder Model

# %%
n_features = 1
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], n_features))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], n_features))

model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(LSTM(100, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(1)))
model.compile(optimizer='adam', loss='mse')

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=72, validation_data=(X_test, y_test), verbose=1, shuffle=False)
#  print history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('
# Epoch 26/50
# 6/6 [==============================] - 0s 8ms/step - loss: 75.6031 - val_loss: 0.0835
# Epoch 27/50
# 6/6 [==============================] - 0s 8ms/step - loss: 74.0023 - val_loss: 0.1233
# Epoch 28/50
# 6/6 [==============================] - 0s 8ms/step - loss: 73.4533 - val_loss: 0.2529
# Epoch 29/50
# 6/6 [==============================] - 0s 8ms/step - loss: 72.9980 - val_loss: 0.6889
# Epoch 30/50
# 6/6 [==============================] - 0s 8ms/step - loss: 74.1556 - val_loss: 2.2579
# Epoch 31/50
# 6/6 [==============================] - 0s 8ms/step - loss: 75.0623 - val_loss: 4.0320
# Epoch 32/50
# 6/6 [==============================] - 0s 8ms/step - loss: 75.0546 - val_loss: 0.0368
# Epoch 33/50
# 6/6 [==============================] - 0s 8ms/step - loss: 72.4935 - val_loss: 0.1001
# Epoch 34/50
# 6/6 [==============================] - 0s 8ms/step - loss: 72.3291 - val_loss: 0.4191
# Epoch 35/50
# 6/6 [==============================] - 0s 8ms/step - loss: 72.1809 - val_loss: 0.3286
# Epoch 36/50
# 6/6 [==============================] - 0s 8ms/step - loss: 72.2972 - val_loss: 1.2302
# Epoch 37/50
# 6/6 [==============================] - 0s 9ms/step - loss: 72.6252 - val_loss: 2.9884
# Epoch 38/50
# 6/6 [==============================] - 0s 9ms/step - loss: 72.8838 - val_loss: 2.0787
# Epoch 39/50
# 6/6 [==============================] - 0s 8ms/step - loss: 71.7052 - val_loss: 0.2693
# Epoch 40/50
# 6/6 [==============================] - 0s 8ms/step - loss: 69.8248 - val_loss: 0.1902
# Epoch 41/50
# 6/6 [==============================] - 0s 8ms/step - loss: 69.2029 - val_loss: 1.1246
# Epoch 42/50
# 6/6 [==============================] - 0s 8ms/step - loss: 69.6278 - val_loss: 0.7479
# Epoch 43/50
# 6/6 [==============================] - 0s 8ms/step - loss: 69.2747 - val_loss: 3.0494
# Epoch 44/50
# 6/6 [==============================] - 0s 9ms/step - loss: 72.1467 - val_loss: 1.8149
# Epoch 45/50
# 6/6 [==============================] - 0s 9ms/step - loss: 73.9733 - val_loss: 2.4050
# Epoch 46/50
# 6/6 [==============================] - 0s 9ms/step - loss: 72.9286 - val_loss: 1.1936
# Epoch 47/50
# 6/6 [==============================] - 0s 8ms/step - loss: 71.9684 - val_loss: 0.8806
# Epoch 48/50
# 6/6 [==============================] - 0s 8ms/step - loss: 71.3546 - val_loss: 1.5158
# Epoch 49/50
# 6/6 [==============================] - 0s 10ms/step - loss: 70.3818 - val_loss: 0.8542
# Epoch 50/50
# 6/6 [==============================] - 0s 9ms/step - loss: 68.7253 - val_loss: 0.0181

# %%
yhat = model.predict(X_test)

#mse = mean_squared_error(y_test, yhat)
#print('Test MSE: %.3f' % mse)

plt.figure()
plt.plot(y_test,color='b', label='real data')
plt.plot(yhat,color='r', label='predictions')
plt.title(company)
plt.xlabel("days")
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 0s 1ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Vasco Costa\OneDrive - Universidade de Aveiro\Grupo\AIA\M6_interpolate.ipynb Cell 10 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Vasco%20Costa/OneDrive%20-%20Universidade%20de%20Aveiro/Grupo/AIA/M6_interpolate.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> #mse = mean_squared_error(y_test, yhat)
#       <a href='vscode-notebook-cell:/c%3A/Users/Vasco%20Costa/OneDrive%20-%20Universidade%20de%20Aveiro/Grupo/AIA/M6_interpolate.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> #print('Test MSE: %.3f' % mse)
#       <a href='vscode-notebook-cell:/c%3A/Users/Vasco%20Costa/OneDrive%20-%20Universidade%20de%20Aveiro/Grupo/AIA/M6_interpolate.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> plt.figure()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Vasco%20Costa/OneDrive%20-%20Universidade%20de%20Aveiro/Grupo/AIA/M6_interpolate.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a> plt.plot(y_test,color='b', label='real data')
#       <a href='vscode-notebook-cell:/c%3A/Users/Vasco%20Costa/OneDrive%20-%20Universidade%20de%20Aveiro/Grupo/AIA/M6_interpolate.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a> plt.plot(yhat,color='r', label='predictions')
#       <a href='vscode-notebook-cell:/c%3A/Users/Vasco%20Costa/OneDrive%20-%20Universidade%20de%20Aveiro/Grupo/AIA/M6_interpolate.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a> plt.title(company)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:501, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     498     raise ValueError(f"x and y must have same first dimension, but "
#     499                      f"have shapes {x.shape} and {y.shape}")
#     500 if x.ndim > 2 or y.ndim > 2:
# --> 501     raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                      f"shapes {x.shape} and {y.shape}")
#     503 if x.ndim == 1:
#     504     x = x[:, np.newaxis]
#
# ValueError: x and y can be no greater than 2D, but have shapes (101,) and (101, 2, 1)
