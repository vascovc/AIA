# %% [markdown]
# Stacked LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,LSTM
from datetime import datetime
import sys

from read_files import read_files

import matplotlib.pyplot as plt

# %%
path = "C:/Users/Vasco/OneDrive - Universidade de Aveiro/Grupo/AIA/" #o teu path
path = "C:/Users/Vasco Costa/OneDrive - Universidade de Aveiro/Grupo/AIA/" #o teu path
product_group_id = 958 #depende da pasta
time_series_folder = 1 #1,2,3

df_long, df_wide = read_files(path,product_group_id,time_series_folder)
product_information = pd.read_pickle(path+"Data/product_information")
#print(product_information.loc[product_group_id])
#print(df_wide)
#print(df_wide.columns)
i = 1
plt.figure()
for col in df_wide.columns:
    plt.subplot(len(df_wide.columns), 1, i)
    plt.plot(df_wide[col].values)
    plt.title(col)
    i += 1
plt.show()

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X),np.array(y)

# %%
methods= ["linear","time","slinear","quadratic","cubic","barycentric",
        "krogh", "from_derivatives", "pchip", "akima", "cubicspline"]
orders = ["polynomial","spline"]
methods += orders
order = 5

method = methods[1]
#for name in df_wide.columns:
if method in orders:
    df_wide.interpolate(option=method,order=order,inplace=True,limit_direction="both")
else:
    df_wide.interpolate(option=method,inplace=True,limit_direction="both")

i = 1
plt.figure()
for col in df_wide.columns:
    plt.subplot(len(df_wide.columns), 1, i)
    plt.plot(df_wide[col].values)
    plt.title(col)
    i += 1
plt.show()

# %%
company = "Abcdin"
raw_seq = df_wide[company]
n_steps = 7
X, y = split_sequence(raw_seq, n_steps)
percent_train = 0.8
value = int(len(X)*percent_train)
#print(len(X))
X_train = X[:value]
#print(len(X_train))
y_train = y[:value]
X_test = X[value:]
#print(len(X_test))
y_test = y[value:]

# %% [markdown]
# Stacked LSTM

# %%
n_features = 1
X = X.reshape((X.shape[0],X.shape[1],n_features))

model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=72, validation_data=(X_test, y_test), verbose=1, shuffle=False)
#  print history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('
# 6/6 [==============================] - 0s 9ms/step - loss: 80.5921 - val_loss: 5.2076
# Epoch 29/50
# 6/6 [==============================] - 0s 9ms/step - loss: 79.7022 - val_loss: 1.3952
# Epoch 30/50
# 6/6 [==============================] - 0s 10ms/step - loss: 77.1199 - val_loss: 0.0809
# Epoch 31/50
# 6/6 [==============================] - 0s 9ms/step - loss: 74.3882 - val_loss: 0.0289
# Epoch 32/50
# 6/6 [==============================] - 0s 9ms/step - loss: 72.6624 - val_loss: 0.1963
# Epoch 33/50
# 6/6 [==============================] - 0s 10ms/step - loss: 70.6154 - val_loss: 1.5370
# Epoch 34/50
# 6/6 [==============================] - 0s 9ms/step - loss: 69.3009 - val_loss: 3.1967
# Epoch 35/50
# 6/6 [==============================] - 0s 9ms/step - loss: 68.6985 - val_loss: 2.7523
# Epoch 36/50
# 6/6 [==============================] - 0s 9ms/step - loss: 68.6641 - val_loss: 2.1358
# Epoch 37/50
# 6/6 [==============================] - 0s 10ms/step - loss: 66.9237 - val_loss: 3.0004
# Epoch 38/50
# 6/6 [==============================] - 0s 9ms/step - loss: 65.3871 - val_loss: 4.0100
# Epoch 39/50
# 6/6 [==============================] - 0s 10ms/step - loss: 64.0726 - val_loss: 3.7396
# Epoch 40/50
# 6/6 [==============================] - 0s 10ms/step - loss: 63.0687 - val_loss: 2.5728
# Epoch 41/50
# 6/6 [==============================] - 0s 9ms/step - loss: 61.9517 - val_loss: 0.8804
# Epoch 42/50
# 6/6 [==============================] - 0s 9ms/step - loss: 60.9965 - val_loss: 2.1659e-05
# Epoch 43/50
# 6/6 [==============================] - 0s 10ms/step - loss: 60.8381 - val_loss: 0.1912
# Epoch 44/50
# 6/6 [==============================] - 0s 9ms/step - loss: 60.8860 - val_loss: 0.1103
# Epoch 45/50
# 6/6 [==============================] - 0s 9ms/step - loss: 60.6282 - val_loss: 0.0351
# Epoch 46/50
# 6/6 [==============================] - 0s 9ms/step - loss: 60.3894 - val_loss: 3.5512e-04
# Epoch 47/50
# 6/6 [==============================] - 0s 9ms/step - loss: 60.1231 - val_loss: 0.0235
# Epoch 48/50
# 6/6 [==============================] - 0s 9ms/step - loss: 60.1335 - val_loss: 0.0254
# Epoch 49/50
# 6/6 [==============================] - 0s 9ms/step - loss: 59.9165 - val_loss: 0.0499
# Epoch 50/50
# 6/6 [==============================] - 0s 9ms/step - loss: 59.7700 - val_loss: 0.0019

# %%
yhat = model.predict(X_test)

mse = mean_squared_error(y_test, yhat)
print('Test MSE: %.3f' % mse)

plt.figure()
plt.plot(y_test,color='b', label='real data')
plt.plot(yhat,color='r', label='predictions')
plt.title(company)
plt.xlabel("days")
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step
# Test MSE: 0.002
