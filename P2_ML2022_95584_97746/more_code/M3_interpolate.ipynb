# %% [markdown]
# Bidirectional LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,LSTM,Bidirectional
from datetime import datetime
import sys

from read_files import read_files

import matplotlib.pyplot as plt

# %%
path = "C:/Users/Vasco/OneDrive - Universidade de Aveiro/Grupo/AIA/" #o teu path
path = "C:/Users/Vasco Costa/OneDrive - Universidade de Aveiro/Grupo/AIA/" #o teu path
product_group_id = 958 #depende da pasta
time_series_folder = 1 #1,2,3

df_long, df_wide = read_files(path,product_group_id,time_series_folder)
product_information = pd.read_pickle(path+"Data/product_information")
#print(product_information.loc[product_group_id])
#print(df_wide)
#print(df_wide.columns)
i = 1
plt.figure()
for col in df_wide.columns:
    plt.subplot(len(df_wide.columns), 1, i)
    plt.plot(df_wide[col].values)
    plt.title(col)
    i += 1
plt.show()

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X),np.array(y)

# %%
methods= ["linear","time","slinear","quadratic","cubic","barycentric",
        "krogh", "from_derivatives", "pchip", "akima", "cubicspline"]
orders = ["polynomial","spline"]
methods += orders
order = 5

method = methods[1]
#for name in df_wide.columns:
if method in orders:
    df_wide.interpolate(option=method,order=order,inplace=True,limit_direction="both")
else:
    df_wide.interpolate(option=method,inplace=True,limit_direction="both")

i = 1
plt.figure()
for col in df_wide.columns:
    plt.subplot(len(df_wide.columns), 1, i)
    plt.plot(df_wide[col].values)
    plt.title(col)
    i += 1
plt.show()

# %%
company = "Abcdin"
raw_seq = df_wide[company]
n_steps = 7
X, y = split_sequence(raw_seq, n_steps)
percent_train = 0.8
value = int(len(X)*percent_train)
#print(len(X))
X_train = X[:value]
#print(len(X_train))
y_train = y[:value]
X_test = X[value:]
#print(len(X_test))
y_test = y[value:]

# %% [markdown]
# Bidirectional LSTM

# %%
n_features = 1
X = X.reshape((X.shape[0],X.shape[1],n_features))

model = Sequential()
model.add(Bidirectional(LSTM(50, activation='relu'), input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=72, validation_data=(X_test, y_test), verbose=1, shuffle=False)
#  print history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('
# 6/6 [==============================] - 0s 7ms/step - loss: 56.8836 - val_loss: 3.2907
# Epoch 29/50
# 6/6 [==============================] - 0s 7ms/step - loss: 55.8665 - val_loss: 0.1145
# Epoch 30/50
# 6/6 [==============================] - 0s 7ms/step - loss: 54.5096 - val_loss: 0.4118
# Epoch 31/50
# 6/6 [==============================] - 0s 7ms/step - loss: 54.8462 - val_loss: 2.6538
# Epoch 32/50
# 6/6 [==============================] - 0s 7ms/step - loss: 55.6162 - val_loss: 2.3578
# Epoch 33/50
# 6/6 [==============================] - 0s 7ms/step - loss: 55.1100 - val_loss: 0.8394
# Epoch 34/50
# 6/6 [==============================] - 0s 7ms/step - loss: 54.3177 - val_loss: 0.6501
# Epoch 35/50
# 6/6 [==============================] - 0s 7ms/step - loss: 53.7584 - val_loss: 0.2297
# Epoch 36/50
# 6/6 [==============================] - 0s 7ms/step - loss: 53.5194 - val_loss: 0.2152
# Epoch 37/50
# 6/6 [==============================] - 0s 7ms/step - loss: 53.5368 - val_loss: 0.2381
# Epoch 38/50
# 6/6 [==============================] - 0s 7ms/step - loss: 53.2215 - val_loss: 0.0199
# Epoch 39/50
# 6/6 [==============================] - 0s 7ms/step - loss: 53.6230 - val_loss: 0.0792
# Epoch 40/50
# 6/6 [==============================] - 0s 7ms/step - loss: 53.1095 - val_loss: 0.0360
# Epoch 41/50
# 6/6 [==============================] - 0s 8ms/step - loss: 53.8575 - val_loss: 0.0667
# Epoch 42/50
# 6/6 [==============================] - 0s 8ms/step - loss: 53.6048 - val_loss: 0.4099
# Epoch 43/50
# 6/6 [==============================] - 0s 8ms/step - loss: 53.2643 - val_loss: 0.0222
# Epoch 44/50
# 6/6 [==============================] - 0s 7ms/step - loss: 53.0652 - val_loss: 0.0459
# Epoch 45/50
# 6/6 [==============================] - 0s 7ms/step - loss: 53.8909 - val_loss: 0.0125
# Epoch 46/50
# 6/6 [==============================] - 0s 7ms/step - loss: 53.5319 - val_loss: 0.7441
# Epoch 47/50
# 6/6 [==============================] - 0s 7ms/step - loss: 52.7924 - val_loss: 0.0088
# Epoch 48/50
# 6/6 [==============================] - 0s 7ms/step - loss: 52.6484 - val_loss: 0.0730
# Epoch 49/50
# 6/6 [==============================] - 0s 7ms/step - loss: 53.3368 - val_loss: 0.0036
# Epoch 50/50
# 6/6 [==============================] - 0s 8ms/step - loss: 52.6606 - val_loss: 0.0343

# %%
yhat = model.predict(X_test)

mse = mean_squared_error(y_test, yhat)
print('Test MSE: %.3f' % mse)

plt.figure()
plt.plot(y_test,color='b', label='real data')
plt.plot(yhat,color='r', label='predictions')
plt.title(company)
plt.xlabel("days")
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 0s 1ms/step
# Test MSE: 0.034
